# %%
print(f'Init')
import cv2
import matplotlib.pyplot as plt
pth = 'static/images/best_home.png'
img = cv2.imread(pth)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# Init

# %%
img.shape
# Out:
# (2040, 2210, 3)

# %%
def change_px(px):
    if(px[0] == 73 and px[1] == 91 and px[2] == 109):
        return False
    elif(px[0] == 135 and px[1] == 205 and px[2] == 188):
        return False
    else:
        return True


for i in range(2040):
    for j in range(2210):
        px = img[i][j]
        if(check_white(px)):
            img[i][j] = [0,0,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 11
#       9 for j in range(2210):
#      10     px = img[i][j]
# ---> 11     if(check_white(px)):
#      12         img[i][j] = [0,0,0]
#
# Cell In[15], line 2, in check_white(px)
#       1 def check_white(px):
# ----> 2     if(px != (255, 255, 255)):
#       3         return True
#       4     else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.imshow(img)
plt.show()
